# %% [markdown]
# #### Actividad
#
# $$\phi_1(X, Y)$$
#
# |   X   |   Y   | $\phi_1$ |
# | ----- | ----- | -------- |
# | $x^0$ | $y^0$ | 0.8      |
# | $x^0$ | $y^1$ | 0.5      |
# | $x^1$ | $y^0$ | 0.5      |
# | $x^1$ | $y^1$ | 0.6      |
#
# $$\phi_2(Y, Z)$$
#
# |   Y   |   Z   | $\phi_2$ |
# | ----- | ----- | -------- |
# | $y^0$ | $z^0$ | 0.2      |
# | $y^0$ | $z^1$ | 0.2      |
# | $y^1$ | $z^0$ | 0.9      |
# | $y^1$ | $z^1$ | 1.0      |
#
# Si $\psi(X,Y,Z) = \phi_1(X, Y) \phi_2(Y,Z)$
# - $\psi(x^0, y^0, z^0)=?$
# - $\psi(x^0, y^1, z^1)=?$
# - $\psi(x^1, y^1, z^1)=?$

# %% [markdown]
# ---

# %% [markdown]
# ### Actividad:
# $$\phi_1(X, Y)$$
#
# |   X   |   Y   | $\phi_1$ |
# | ----- | ----- | -------- |
# | $x^0$ | $y^0$ | 0.8      |
# | $x^0$ | $y^1$ | 0.5      |
# | $x^1$ | $y^0$ | 0.5      |
# | $x^1$ | $y^1$ | 0.6      |
#
# Si $\psi(Y) = \sum_{X}\phi_1(X, Y)$
#
# - $\psi(y^0)=$?
# - $\psi(y^1)=$?

# %% [markdown]
# ---

# %% [markdown]
# ### Actividad:
# $$\phi_1(X, Y)$$
#
# |   X   |   Y   | $\phi_1$ |
# | ----- | ----- | -------- |
# | $x^0$ | $y^0$ | 0.8      |
# | $x^0$ | $y^1$ | 0.5      |
# | $x^1$ | $y^0$ | 0.5      |
# | $x^1$ | $y^1$ | 0.6      |
#
# Si $\psi(X) = \phi_1(X, y^0)$
#
# - $\psi(x^0)=$?
# - $\psi(x^1)=$?
